# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr

# %%
data = pd.read_csv('sales_train_validation.csv')
stores_CA = data.loc[data.state_id == 'CA'].store_id.unique()
store = stores_CA[0]
data_store = data.loc[data.store_id == store]
cats = data_store.cat_id.unique()
cat = cats[0]
data_store_cat = data_store.loc[data_store.cat_id == cat]
data_sales = data_store_cat[data_store_cat.columns[6:]].T
data_sales.columns = data_store_cat.id

# %%
data_sales
# Out:
# id      HOBBIES_1_001_CA_1_validation  HOBBIES_1_002_CA_1_validation  \
# d_1                                 0                              0
# d_2                                 0                              0
# d_3                                 0                              0
# d_4                                 0                              0
# d_5                                 0                              0
# ...                               ...                            ...
# d_1909                              1                              1
# d_1910                              3                              0
# d_1911                              0                              0
# d_1912                              1                              0
# d_1913                              1                              0
#
# id      HOBBIES_1_003_CA_1_validation  HOBBIES_1_004_CA_1_validation  \
# ...

# %%
columns = data_sales.columns
shape = data_sales.shape[1]

# %%
corr = pd.DataFrame(data=np.full((shape, shape), np.nan),
                        columns=columns, index=columns)

# %%
corr
# Out:
# id                             HOBBIES_1_001_CA_1_validation  \
# id
# HOBBIES_1_001_CA_1_validation                            NaN
# HOBBIES_1_002_CA_1_validation                            NaN
# HOBBIES_1_003_CA_1_validation                            NaN
# HOBBIES_1_004_CA_1_validation                            NaN
# HOBBIES_1_005_CA_1_validation                            NaN
# ...                                                      ...
# HOBBIES_2_145_CA_1_validation                            NaN
# HOBBIES_2_146_CA_1_validation                            NaN
# HOBBIES_2_147_CA_1_validation                            NaN
# HOBBIES_2_148_CA_1_validation                            NaN
# HOBBIES_2_149_CA_1_validation                            NaN
#
# id                             HOBBIES_1_002_CA_1_validation  \
# id
# HOBBIES_1_001_CA_1_validation                            NaN
# HOBBIES_1_002_CA_1_validation                            NaN
# ...

# %%
for col1 in columns:
    for col2 in columns:
        corr.loc[col1, col2] = pearsonr(
            data_sales[col1], data_sales[col2])[0]

# %%
corr
# Out:
# id                             HOBBIES_1_001_CA_1_validation  \
# id
# HOBBIES_1_001_CA_1_validation                       1.000000
# HOBBIES_1_002_CA_1_validation                       0.043393
# HOBBIES_1_003_CA_1_validation                       0.173605
# HOBBIES_1_004_CA_1_validation                       0.188614
# HOBBIES_1_005_CA_1_validation                       0.050161
# ...                                                      ...
# HOBBIES_2_145_CA_1_validation                       0.052642
# HOBBIES_2_146_CA_1_validation                       0.005271
# HOBBIES_2_147_CA_1_validation                       0.138002
# HOBBIES_2_148_CA_1_validation                       0.087955
# HOBBIES_2_149_CA_1_validation                       0.113211
#
# id                             HOBBIES_1_002_CA_1_validation  \
# id
# HOBBIES_1_001_CA_1_validation                       0.043393
# HOBBIES_1_002_CA_1_validation                       1.000000
# ...

# %%
corr.to_csv('corr.csv')

# %%
p = pd.read_csv('prices_CA.csv')

# %%
p
# Out:
#       Unnamed: 0  Unnamed: 0.1        date  wm_yr_wk  \
# 0              0             0  2011-01-29     11101
# 1              1             1  2011-01-30     11101
# 2              2             2  2011-01-31     11101
# 3              3             3  2011-02-01     11101
# 4              4             4  2011-02-02     11101
# ...          ...           ...         ...       ...
# 1964        1964          1964  2016-06-15     11620
# 1965        1965          1965  2016-06-16     11620
# 1966        1966          1966  2016-06-17     11620
# 1967        1967          1967  2016-06-18     11621
# 1968        1968          1968  2016-06-19     11621
#
#       HOBBIES_1_001_CA_1_validation  HOBBIES_1_002_CA_1_validation  \
# 0                              0.00                           0.00
# 1                              0.00                           0.00
# 2                              0.00                           0.00
# ...

# %%
p = p[p.columns[2:]]

# %%
p = p.set_index('date')

# %%
p.to_csv('prices_CA.csv')

# %%
p
# Out:
#             wm_yr_wk  HOBBIES_1_001_CA_1_validation  \
# date
# 2011-01-29     11101                           0.00
# 2011-01-30     11101                           0.00
# 2011-01-31     11101                           0.00
# 2011-02-01     11101                           0.00
# 2011-02-02     11101                           0.00
# ...              ...                            ...
# 2016-06-15     11620                           8.38
# 2016-06-16     11620                           8.38
# 2016-06-17     11620                           8.38
# 2016-06-18     11621                           8.38
# 2016-06-19     11621                           8.38
#
#             HOBBIES_1_002_CA_1_validation  HOBBIES_1_003_CA_1_validation  \
# date
# 2011-01-29                           0.00                           0.00
# 2011-01-30                           0.00                           0.00
# 2011-01-31                           0.00                           0.00
# ...
